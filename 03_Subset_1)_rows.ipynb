# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus1286/pandas/blob/main/03_Subset_1)_rows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [참고] <a href="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Pandas Cheat Sheet</a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. row 기준
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1) head / tail

# %%
df = pd.DataFrame(
    {
        "a":[4,5,6, 6,np.nan],
        "b":[7,8,np.nan,9, 9],
        "c":[10,11,12,np.nan, 12],
    },
    index=[1,2,3,4,5]
)
df
# Out:
#      a    b     c
# 1  4.0  7.0  10.0
# 2  5.0  8.0  11.0
# 3  6.0  NaN  12.0
# 4  6.0  9.0   NaN
# 5  NaN  9.0  12.0

# %%
# head()
df.head()
# Out:
#      a    b     c
# 1  4.0  7.0  10.0
# 2  5.0  8.0  11.0
# 3  6.0  NaN  12.0
# 4  6.0  9.0   NaN
# 5  NaN  9.0  12.0

# %%
df.head(2)
# Out:
#      a    b     c
# 1  4.0  7.0  10.0
# 2  5.0  8.0  11.0

# %%
df.tail(2)
# Out:
#      a    b     c
# 4  6.0  9.0   NaN
# 5  NaN  9.0  12.0

# %% [markdown]
# ### 2) sample

# %%
# frac : 비율
# Out:
#      a    b     c
# 4  6.0  9.0   NaN
# 5  NaN  9.0  12.0

# %%
# 임의의 한 개의 행
df.sample()
# Out:
#      a    b     c
# 1  4.0  7.0  10.0

# %%
# n의 개수는 전체의 행 수를 넘어서 지정하면 에러 발생
# 임의로 3개 가져오기

df.sample(n=3)
# Out:
#      a    b     c
# 2  5.0  8.0  11.0
# 4  6.0  9.0   NaN
# 3  6.0  NaN  12.0

# %% [markdown]
# ### 3) nlargest / nsmallest

# %%
df.nlargest?

# %%
# a 컬럼에서 가장 큰 값 세 개 추출
df.nlargest(3,"a")
# Out:
#      a    b     c
# 3  6.0  NaN  12.0
# 4  6.0  9.0   NaN
# 2  5.0  8.0  11.0

# %%
df.nlargest(1,"c")
# Out:
#      a   b     c
# 3  6.0 NaN  12.0

# %%
df.nsmallest(2, "a")
# Out:
#      a    b     c
# 1  4.0  7.0  10.0
# 2  5.0  8.0  11.0

# %% [markdown]
# ### 4) 중복 행 제거 : drop_duplicates()
#
#
# ```
# df.drop_duplicates(
#     subset: Union[Hashable, Sequence[Hashable], NoneType] = None,
#     keep: Union[str, bool] = 'first',
#     inplace: bool = False,
#     ignore_index: bool = False,
# ) -> Union[ForwardRef('DataFrame'), NoneType]
# ```

# %%
df = pd.DataFrame({"a":[4,5,6,6], "b":[7,8,9,9], "c":[10,11,12,12]}, index=["a", "b", "c", "d"])
df
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12
# d  6  9  12

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#    a  b   c
# a  4  7  10
# b  5  8  11
# c  6  9  12

# %% [markdown]
# ### 5) 불린 인덱싱

# %%
friend_dict_list = [
    {"name":"John",
    "age":25,
    "job":"student"},
    {"name":"Nate",
    "age":34,
    "job":"teacher"},
    {"name":"Jenny",
    "age":30,
    "job":"developer"}
]

friend_df = pd.DataFrame(friend_dict_list)
friend_df
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
# 나이가 >25
# friend_df["age"] > 25
friend_df.age > 25
# Out:
# 0    False
# 1     True
# 2     True
# Name: age, dtype: bool

# %%
friend_df[friend_df.age > 25]
# Out:
#     name  age        job
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
friend_df[friend_df.age > 30]
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %%
# 나이가 > 25 and name = "Nate"
# pandas : and 안 됨
# friend_df[(friend_df.age > 25) and (friend_df.name == "Nate")]

(friend_df.age > 25) & (friend_df.name == "Nate")
friend_df[(friend_df.age > 25) & (friend_df.name == "Nate")]
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %%
friend_df[friend_df.name=="Jenny"]
# Out:
#     name  age        job
# 2  Jenny   30  developer

# %% [markdown]
# ### 6) query()

# %%
friend_df.query("age > 25")
# Out:
#     name  age        job
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
friend_df.query("age > 25" and "name == 'Nate'")
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %% [markdown]
# #### [실습] friend_df

# %% [markdown]
# #### 1) head()

# %%
friend_df.head()
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
friend_df.head(3)
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %% [markdown]
# #### 2) tail()

# %%
friend_df.tail()
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %%
friend_df.tail(3)
# Out:
#     name  age        job
# 0   John   25    student
# 1   Nate   34    teacher
# 2  Jenny   30  developer

# %% [markdown]
# #### 3) nlargest()

# %%
# age 가 가장 큰
friend_df.nlargest(1,"age")
# Out:
#    name  age      job
# 1  Nate   34  teacher

# %% [markdown]
# #### 4) nsmallest()

# %%
# age 가 가장 작은
friend_df.nsmallest(1,"age")
# Out:
#    name  age      job
# 0  John   25  student

# %% [markdown]
# #### 5) sample()

# %%
friend_df.sample()
# Out:
#    name  age      job
# 0  John   25  student

# %%
friend_df.sample(2)
# Out:
#    name  age      job
# 1  Nate   34  teacher
# 0  John   25  student

# %% [markdown]
# #### [실습] drop_duplicates()

# %%
dict3 = {
    "name":["John", "Nate", "Edward", "Zara", "John"],
    "major":["Computer Science","Computer Science","Computer Science","Psychology", "Computer Science"],
    "gender" : ["male","male","male","female","male"]
}

data = pd.DataFrame(dict3)
data
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female
# 4    John  Computer Science    male

# %%
data.drop_duplicates()
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female

# %%
# drop_duplicates() 의 동작기준 : duplicated() 의 결과값이 True인 행 삭제
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female

# %%
dict3 = {
    "name":["John", "Nate", "Edward", "Zara", "Wendy", "Nate", "John"],
    "major":["Computer Science","Computer Science","Computer Science","Psychology","Economics", "None" ,"Economics"],
    "gender" : ["male","male","male","female","female", "male", "male"]
}

data = pd.DataFrame(dict3)
data
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female
# 4   Wendy         Economics  female
# 5    Nate              None    male
# 6    John         Economics    male

# %%
# 행의 값이 완전히 동일할 때만 일치
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
# 이름이 동일한 경우 중복이라고 인식시키기
data.duplicated("name")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
# keep = : 중복 데이터 중 어느 행을 살릴것인지 기준 (기본값은 first)
data.drop_duplicates("name", keep="first")
# Out:
#      name             major  gender
# 0    John  Computer Science    male
# 1    Nate  Computer Science    male
# 2  Edward  Computer Science    male
# 3    Zara        Psychology  female
# 4   Wendy         Economics  female
