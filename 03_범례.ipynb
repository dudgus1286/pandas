# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus1286/pandas/blob/main/03_%EB%B2%94%EB%A1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## matplotlib (https://matplotlib.org/stable/index)
#
# - 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %% [markdown]
# ### 범례 설정
# - https://matplotlib.org/stable/api/legend_api.html

# %%
# matplotlib 한글 처리
# !pip install koreanize_matplotlib

# 나눔 글꼴 설치
# !apt -qq -y install fonts-nanum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 23.5 MB/s eta 0:00:00
# ...
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# import 구문
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
# matplotlib 에서 해당 폰트를 사용할 수 있도록 등록
all_fonts_I_can_use = fm.findSystemFonts(fontpaths=None, fontext='ttf')
for f_path in all_fonts_I_can_use:
  fm.fontManager.addfont(f_path)

# matplotlib 기본 글꼴 설정
plt.rc("font", family="NanumBarunGothic")

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x,y, label="데이터")
plt.legend();

# %% [markdown]
# - 두 개의 선을 하나의 차트에 그릴 때

# %%
x1 = [1, 2, 3]
y1 = [1, 2, 3]
x2 = [1, 2, 3]
y2 = [1, 4, 7]

# %%
plt.plot(x1, y1, label="data1", color="red")
plt.plot(x2, y2, label="data2", color="blue")
plt.legend();

# %%
plt.plot(x1, y1,  color="red")
plt.plot(x2, y2,  color="blue")
plt.legend(["data1", "data2"]);

# %% [markdown]
# ><b>1) 범례 위치 설정</b>

# %% [markdown]
# - 범례 위치 지정하기 - 기본은 5
# - 0 or 아무값도 안 주면 그래프에 따라 자동으로 위치 지정
#
# <table border="1" align="left">
#     <tr>
#         <td>2(upper left)</td>
#         <td>9(upper center)</td>
#         <td>1(upper right)</td>
#     </tr>
#     <tr>
#         <td>6(center left)</td>
#         <td>10(center)</td>
#         <td>5(right),7(center right)</td>
#     </tr>
#     <tr>
#         <td>3(lower left)</td>
#         <td>8(lower center)</td>
#         <td>4(lower right)</td>
#     </tr>
# </table>
#
# <br><br>

# %%
plt.plot(x, y)
plt.legend(["데이터"], loc="upper right");

# %%
plt.plot(x, y)
plt.legend(["데이터"], loc=5);

# %%
plt.plot(x, y)
plt.legend(["데이터"], loc=9);

# %%
plt.plot(x, y)
plt.legend(["데이터"], loc="center");

# %%
plt.plot(x, y)
# 0 ~ 1 사이의 값
plt.legend(["데이터"], loc=(0.5,0.5));

# %% [markdown]
# ><b>2) 범례 폰트 사이즈 지정</b>

# %%
plt.plot(x1, y1,  color="red")
plt.plot(x2, y2,  color="blue")
plt.legend(["data1", "data2"], fontsize=20);

# %% [markdown]
# ><b>3) 범례 행 수 지정</b>

# %%
plt.plot(x1, y1,  color="red")
plt.plot(x2, y2,  color="blue")
plt.legend(["data1", "data2"], ncol=2);

# %% [markdown]
# - [학생문제] : data1(x : 1, 2, 3; y : 1, 2, 3) 과 data2(x : 1, 2, 3; y : 1, 100, 200) 을 그래프로 출력하시오.

# %%
x1 = [1, 2, 3]
y1 = [1, 2, 3]
x2 = [1, 2, 3]
y2 = [1, 100, 200]

# %%
plt.plot(x1,y1,color="blue", label="data1")
plt.plot(x2,y2,color="red", label="data2")
