# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus1286/pandas/blob/main/matplotlib/04_%EC%8A%A4%ED%83%80%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## matplotlib (https://matplotlib.org/stable/index)
#
# - 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
# matplotlib 한글 처리
# !pip install koreanize_matplotlib

# 나눔 글꼴 설치
# !apt -qq -y install fonts-nanum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 14.4 MB/s eta 0:00:00
# ...
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# import 구문
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
all_fonts_I_can_use = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# %%
# matplotlib 에서 해당 폰트를 사용할 수 있도록 등록

for f_path in all_fonts_I_can_use:
  fm.fontManager.addfont(f_path)

# matplotlib 기본 글꼴 설정
plt.rc("font", family="NanumBarunGothic")

# %%
x = [1,2,3]
y = [2,4,8]

# %% [markdown]
# #### 1. 선 굵기 : linewidth

# %%
plt.plot(x,y,linewidth=10);

# %% [markdown]
# #### 2. 마커
# - https://matplotlib.org/stable/gallery/lines_bars_and_markers/marker_reference.html

# %%
plt.plot(x, y, marker="o");

# %%
# 마커 사이즈 변경

plt.plot(x, y, marker="o", markersize=10);

# %%
plt.plot([4,5,6],marker="o")
plt.plot([3,4,5],marker="d")
plt.plot([2,3,4],marker="x")
plt.plot([1,2,3],marker=11)
plt.plot([0,1,2],marker="$Z$")

# %%
# markeredgecolor : 마커 테두리 색상
# markerfacecolor : 마커 색상

plt.plot(x,y,marker="o", markersize=20, markeredgecolor="red", markerfacecolor="yellow")

# %% [markdown]
# #### 3. 선 모양 : linestyle(https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html)

# %%
plt.plot(x,y, linewidth=5, linestyle="--");

# %%
plt.plot(x,y, linewidth=5, linestyle="-.");

# %%
plt.plot(x,y, linewidth=5, linestyle=":");

# %% [markdown]
# #### 4. 선 색상 : color
#
# - https://matplotlib.org/stable/api/colors_api.html#module-matplotlib.colors

# %%
plt.plot(x,y, linewidth=5, color="r");

# %%
plt.plot(x,y, linewidth=5, color="b");

# %%
plt.plot(x,y, linewidth=5, color="g");

# %% [markdown]
# #### 5. 포맷 - fmt = '[marker][line][color]'

# %%
plt.plot(x,y, 'o');

# %%
plt.plot(x,y, 'ro');

# %%
plt.plot(x,y, 'ro--');

# %%
plt.plot(x,y, 'bv:');

# %%
plt.plot(x,y, 'go');

# %% [markdown]
# #### 6. 축약(https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
# mfc : markerfacecolor
# mec : markeredgecolor
# ls : linestyle

plt.plot(x,y,marker="o", mfc="r", mec="b", ls=":", ms=10);

# %% [markdown]
# #### 7. 투명도

# %%
plt.plot(x,y,marker="o", mfc="r", mec="b", ms=10, alpha=0.3);

# %% [markdown]
# #### 8. 그래프 크기

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y);

# %%
plt.figure(figsize=(5,10))
plt.plot(x,y);

# %%
# dpi : 해상도
plt.figure(figsize=(10,5), dpi=200)
plt.plot(x,y);

# %% [markdown]
# #### 9. 배경색

# %%
plt.figure(facecolor="yellow")
plt.plot(x,y);
