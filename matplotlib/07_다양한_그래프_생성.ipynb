# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus1286/pandas/blob/main/matplotlib/07_%EB%8B%A4%EC%96%91%ED%95%9C_%EA%B7%B8%EB%9E%98%ED%94%84_%EC%83%9D%EC%84%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# matplotlib 한글 처리

# !pip install koreanize_matplotlib

# 나눔 글꼴 설치
# !apt -qq -y install fonts-nanum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 14.1 MB/s eta 0:00:00
# ...
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
for fpath in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
  fm.fontManager.addfont(fpath)

plt.rc("font",family='NanumBarunGothic')

# %% [markdown]
# ### 1) 막대차트(기본)

# %%
values= [175, 187, 184]
labels= ["강백호", "서태웅", "정대만"]

plt.bar(labels, values);

# %% [markdown]
# ><b>색상</b>

# %%
plt.bar(labels, values, color="red");

# %%
plt.bar(labels, values, color=["red", "green", "blue"]);

# %%
plt.bar(labels, values, color=['r','g','b'], alpha=0.5);

# %% [markdown]
# ><b>축 레이블 조정</b>

# %%
plt.bar(labels, values)
# y축 범위 설정
plt.ylim(175, 190);

# %% [markdown]
# ><b>막대 너비 조정</b>

# %%
plt.bar(labels, values, width = 0.3);

# %% [markdown]
# ><b>축 레이블 rotation 설정</b>

# %%
plt.bar(labels, values, width = 0.3)
plt.xticks(rotation=45)
plt.yticks(rotation=45);

# %% [markdown]
# ><b>막대 </b>

# %%
plt.bar(labels, values, width = 0.3)
xticks=["1번학생", "2번학생", "3번학생"]
plt.xticks(labels, xticks);

# %% [markdown]
# ### 2) 막대차트(심화)

# %% [markdown]
# **수평막대**

# %%
plt.barh(labels,values);

# %%
plt.barh(labels, values)
plt.xlim(170, 195);

# %% [markdown]
# **막대 패턴**(https://matplotlib.org/stable/gallery/shapes_and_collections/hatch_style_reference.html)

# %%
bar = plt.bar(labels,values);
bar[0].set_hatch("/")
bar[1].set_hatch("x")
bar[2].set_hatch("o")

# %%
bar = plt.bar(labels, values)
plt.ylim(170,195)

for idx,rect in enumerate(bar):
  plt.text(idx, rect.get_height() + 0.5, values[idx], ha="center")
