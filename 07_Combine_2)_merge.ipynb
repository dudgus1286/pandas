# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus1286/pandas/blob/main/07_Combine_2)_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [참고] <a href="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Pandas Cheat Sheet</a>

# %% [markdown]
# ## merge
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*ZCpo3gXuXI4KFhKivEt2ZA.png" width="600">

# %% [markdown]
# - merge(데이터프레임1, 데이터프레임2) : 두 데이터프레임에 동일한 이름을 가진 컬럼을 기준으로 두 데이터프레임을 합침

# %% [markdown]
# <img src='https://www.datasciencemadesimple.com/wp-content/uploads/2017/09/join-or-merge-in-python-pandas-1.png?ezimgfmt=ng:webp/ngcb1'>

# %%
import pandas as pd

# %%
pd.merge?

# %%
df1 = pd.DataFrame({
    "x1":["A",'B','C'],
    "x2":[1,2,3]
})
df1
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
df2 = pd.DataFrame({
    "x1":['A','B','D'],
    "x2":['T','F','T']
})
df2
# Out:
#   x1 x2
# 0  A  T
# 1  B  F
# 2  D  T

# %%
pd.merge(df1, df2, how="left", on="x1")
# Out:
#   x1  x2_x x2_y
# 0  A     1    T
# 1  B     2    F
# 2  C     3  NaN

# %%
pd.merge(df1, df2, how="right", on="x1")
# Out:
#   x1  x2_x x2_y
# 0  A   1.0    T
# 1  B   2.0    F
# 2  D   NaN    T

# %%
pd.merge(df1, df2, how="inner", on="x1")
# Out:
#   x1  x2_x x2_y
# 0  A     1    T
# 1  B     2    F

# %%
pd.merge(df1, df2, how="outer", on="x1")
# Out:
#   x1  x2_x x2_y
# 0  A   1.0    T
# 1  B   2.0    F
# 2  C   3.0  NaN
# 3  D   NaN    T

# %% [markdown]
# * Filterling Join

# %%
df2.x1
# Out:
# 0    A
# 1    B
# 2    D
# Name: x1, dtype: object

# %%
df1.x1
# Out:
# 0    A
# 1    B
# 2    C
# Name: x1, dtype: object

# %%
# df1.x1 안의 값과 df2.x1 값이 일치한 경우만 가져오기
# df1의 내용만 가져오기

# isin()
df1[df1["x1"].isin(df2["x1"])]
# Out:
#   x1  x2
# 0  A   1
# 1  B   2

# %%
# ~ : 제외
# df1[~df1.x1.isin(df2.x1)]
df1[df1.x1 != df2.x1]
# Out:
#   x1  x2
# 2  C   3

# %% [markdown]
# * 두 번째 실습 : indicator 옵션 활용하기 + query() + drop()

# %%
df1
# Out:
#   x1 x2
# 0  A  T
# 1  B  F
# 2  D  T

# %%
df3 = pd.DataFrame({"x1":['B','C','D'], "x2": [2,3,4]})
df3
# Out:
#   x1  x2
# 0  B   2
# 1  C   3
# 2  D   4

# %%
pd.merge(df1, df3)
# Out:
#   x1  x2
# 0  B   2
# 1  C   3

# %%
pd.merge(df1, df3, how="outer")
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3
# 3  D   4

# %%
# indicator : 머지 방식 출력(확인용)

pd.merge(df1, df3, how="outer", indicator=True)
# Out:
#   x1  x2      _merge
# 0  A   1   left_only
# 1  B   2        both
# 2  C   3        both
# 3  D   4  right_only

# %%
pd.merge(df1, df3, how="outer", indicator=True).query("_merge == 'left_only'")
# Out:
#   x1  x2     _merge
# 0  A   1  left_only

# %%
pd.merge(df1, df3, how="outer", indicator=True).query("_merge == 'left_only'")\
.drop(columns=['_merge'])
# Out:
#   x1  x2
# 0  A   1

# %% [markdown]
# ### [실습2]

# %%
df1 = pd.DataFrame({
    "id": [1, 2, 3],
    "customer_id": [1, 2, 3],
    "customer_name": [
        "Robert",
        "Peter",
        "Dave",
    ],
})
df1
# Out:
#    id  customer_id customer_name
# 0   1            1        Robert
# 1   2            2         Peter
# 2   3            3          Dave

# %%
df2 = pd.DataFrame({
    "id":[1,2,4],
    "order_id":[100,200,300],
    "order_date":["2021-01-21", "2021-02-03", "2020-10-01"]
})
df2
# Out:
#    id  order_id  order_date
# 0   1       100  2021-01-21
# 1   2       200  2021-02-03
# 2   4       300  2020-10-01

# %%
pd.merge(df1, df2)
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1            1        Robert       100  2021-01-21
# 1   2            2         Peter       200  2021-02-03

# %%
pd.merge(df1, df2, how="outer")
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1          1.0        Robert     100.0  2021-01-21
# 1   2          2.0         Peter     200.0  2021-02-03
# 2   3          3.0          Dave       NaN         NaN
# 3   4          NaN           NaN     300.0  2020-10-01

# %%
pd.merge(df1, df2, how="left")
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1            1        Robert     100.0  2021-01-21
# 1   2            2         Peter     200.0  2021-02-03
# 2   3            3          Dave       NaN         NaN

# %%
pd.merge(df1, df2, how="right")
# Out:
#    id  customer_id customer_name  order_id  order_date
# 0   1          1.0        Robert       100  2021-01-21
# 1   2          2.0         Peter       200  2021-02-03
# 2   4          NaN           NaN       300  2020-10-01

# %% [markdown]
# #### 인덱스가 있다면?

# %%
# 데이터프레임 안 특정 컬럼을 인덱스로 설정 : set_index(컬럼명)
df1.set_index("id", inplace=True)
df1
# Out:
#     customer_id customer_name
# id
# 1             1        Robert
# 2             2         Peter
# 3             3          Dave

# %%
df2.set_index("id", inplace=True)
df2
# Out:
#     order_id  order_date
# id
# 1        100  2021-01-21
# 2        200  2021-02-03
# 4        300  2020-10-01

# %%
# pd.merge(df1, df2) - 오류 남 (인덱스 찾지 못함)
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#     customer_id customer_name  order_id  order_date
# id
# 1             1        Robert       100  2021-01-21
# 2             2         Peter       200  2021-02-03

# %%
pd.merge(df1, df2, left_index=True, right_index=True, how="outer")
# Out:
#     customer_id customer_name  order_id  order_date
# id
# 1           1.0        Robert     100.0  2021-01-21
# 2           2.0         Peter     200.0  2021-02-03
# 3           3.0          Dave       NaN         NaN
# 4           NaN           NaN     300.0  2020-10-01

# %%
pd.merge(df1, df2, left_index=True, right_index=True, how="left")
# Out:
#     customer_id customer_name  order_id  order_date
# id
# 1             1        Robert     100.0  2021-01-21
# 2             2         Peter     200.0  2021-02-03
# 3             3          Dave       NaN         NaN

# %%
pd.merge(df1, df2, left_index=True, right_index=True, how="right")
# Out:
#     customer_id customer_name  order_id  order_date
# id
# 1           1.0        Robert       100  2021-01-21
# 2           2.0         Peter       200  2021-02-03
# 4           NaN           NaN       300  2020-10-01
